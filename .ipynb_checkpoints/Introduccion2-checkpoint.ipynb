# %% [markdown]
# <div style="text-align:center; margin-top:40px;">
#
# <h1 style="
# font-family:'Times New Roman', serif;
# font-size:42px;
# font-weight:bold;
# margin-bottom:10px;
# ">
#
# PAO25_25_02_Python_Datatype
#
# </h1>
#
# <p style="
# font-family:'Times New Roman', serif;
# font-size:22px;
# ">
#
# June 22, 2026
#
# </p>
#
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="attachment:2f6ff568-c263-4840-9a8e-83888474c545.jpg" width="500">
# </div>

# %% [markdown]
# <div style="text-align:center;">
#
# <h2 style="
# font-family:'Times New Roman', serif;
# font-size:30px;
# font-weight:bold;
# ">
#
# 01PAO26-26 - Python 1, Data Types
#
# </h2>
#
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="attachment:33774a4c-6ff1-4278-81b4-a2806fd16917.png" width="600">
# </div>

# %% [markdown]
# <div style="text-align:center; margin-top:30px;">
#
# <h2 style="
# font-family:'Times New Roman', serif;
# font-size:28px;
# font-weight:bold;
# ">
#
# Kevin Xavier Suasnavas Villarreal
#
# </h2>
#
# <p style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# ">
#
# <a href="https://github.com/kevinsuas433/Machine2026.git" target="_blank">
# Link a Github
# </a>
#
# </p>
#
# </div>

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:32px;
# font-weight:bold;
# margin-top:35px;
# margin-bottom:20px;
# ">
#
# 1 Comentarios
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:24px;
# font-weight:bold;
# margin-top:20px;
# margin-bottom:15px;
# ">
#
# 1.0.1 ¿Qué son?
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.7;
# text-align:justify;
# ">
#
# Texto contenido en ficheros Python que es ignorado por el intérprete; es decir, no es ejecutado.
#
# </div>

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:24px;
# font-weight:bold;
# margin-top:30px;
# margin-bottom:15px;
# ">
#
# 1.0.2 ¿Cuál es su utilidad?
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.7;
# ">
#
# <ul>
#
# <li>Se puede utilizar para documentar código y hacerlo más legible.</li>
#
# <li>
# Preferiblemente, trataremos de hacer código fácil de entender y que necesite pocos comentarios, en lugar de vernos forzados a recurrir a los comentarios para explicar el código.
# </li>
#
# </ul>
#
# </div>

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:24px;
# font-weight:bold;
# margin-top:30px;
# margin-bottom:15px;
# ">
#
# 1.0.3 Tipos de comentarios
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:20px;
# font-weight:bold;
# margin-top:20px;
# margin-bottom:10px;
# ">
#
# Comentarios de una línea
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.7;
# ">
#
# <ul>
#
# <li>Texto precedido por <code>#</code>.</li>
#
# <li>Se suele usar para documentar expresiones sencillas.</li>
#
# </ul>
#
# </div>

# %%
# Esto es una instrucción print

print("Hello world")   # Esto es una instrucción print
# Out:
# Hello world

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:20px;
# font-weight:bold;
# margin-top:30px;
# margin-bottom:10px;
# ">
#
# Comentarios de varias líneas
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.7;
# ">
#
# <ul>
#
# <li>
# Texto encapsulado en triples comillas (que pueden ser tanto comillas simples como dobles).
# </li>
#
# <li>
# Se suele usar para documentar bloques de código más significativos.
# </li>
#
# </ul>
#
# </div>

# %%
def producto(x, y):
    '''
    Esta función recibe dos números como parámetros y devuelve
    como resultado el producto de los mismos.
    '''
    return x * y

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:32px;
# font-weight:bold;
# margin-top:35px;
# margin-bottom:20px;
# ">
#
# 2 Literales, variables y tipos de datos básicos
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# text-align:justify;
# ">
#
# De forma muy genérica, al ejecutarse un programa Python, simplemente se realizan operaciones sobre objetos.
#
# <br>
#
# Estos dos términos son fundamentales.
#
# <ul>
#
# <li><b>Objetos:</b> cualquier tipo de datos (números, caracteres o datos más complejos).</li>
#
# <li><b>Operaciones:</b> cómo manipulamos estos datos.</li>
#
# </ul>
#
# <b>Ejemplo:</b>
#
# </div>

# %%
4 + 3
# Out:
# 7

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:28px;
# font-weight:bold;
# margin-top:30px;
# margin-bottom:15px;
# ">
#
# 2.1 Literales
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Python tiene una serie de tipos de datos integrados en el propio lenguaje.</li>
#
# <li>Los literales son expresiones que generan objetos de estos tipos.</li>
#
# <li>
# Estos objetos, según su tipo, pueden ser:
#     <ul style="list-style-type:none;">
#         <li>– Simples o compuestos.</li>
#         <li>– Mutables o inmutables.</li>
#     </ul>
# </li>
#
# </ul>
#
# </div>

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:22px;
# font-weight:bold;
# margin-top:25px;
# margin-bottom:10px;
# ">
#
# Literales simples
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Enteros</li>
#
# <li>Decimales o punto flotante</li>
#
# <li>Booleano</li>
#
# </ul>
#
# </div>

# %%
# print(4)              # número entero
# print(4.2)            # número en coma flotante
# print("Hello world!") # string
# print(False)

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:22px;
# font-weight:bold;
# margin-top:30px;
# margin-bottom:10px;
# ">
#
# Literales compuestos
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Tuplas</li>
#
# <li>Listas</li>
#
# <li>Diccionarios</li>
#
# <li>Conjuntos</li>
#
# </ul>
#
# </div>

# %%
# print([1, 2, 3, 3])                        # Lista - mutable

# print({'Nombre':'John Doe', 'edad':30})   # Diccionario - mutable

# print({1, 2, 3, 3})                        # Conjunto - mutable

# print((4, 5))                             # Tupla - inmutable

# 2, 4                                      # Tupla

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:28px;
# font-weight:bold;
# margin-top:35px;
# margin-bottom:20px;
# ">
#
# 2.2 Variables
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Referencias a objetos.</li>
#
# <li>Las variables y los objetos se almacenan en diferentes zonas de memoria.</li>
#
# <li>Las variables siempre referencian a objetos y nunca a otras variables.</li>
#
# <li>Objetos sí que pueden referenciar a otros objetos. Ejemplo: listas.</li>
#
# <li>
# Sentencia de asignación:
# </li>
#
# </ul>
#
# </div>
#
# <div style="
# font-family:'Courier New', monospace;
# font-size:18px;
# margin-left:40px;
# margin-top:10px;
# margin-bottom:20px;
# ">
#
# &lt;nombre_variable&gt; = &lt;objeto&gt;
#
# </div>

# %%
# Asignación de variables

# a = 5

# print(a)

# %%
# a = 1              # entero
# b = 4.0            # coma flotante
# c = "ITQ"          # string
# d = 10 + 1j        # número complejo
# e = True           # boolean
# f = None           # None

# visualizar valor de las variables y su tipo

# print(a)
# print(type(a))

# print(b)
# print(type(b))

# print(c)
# print(type(c))

# print(d)
# print(type(d))

# print(e)
# print(type(e))

# print(f)
# print(type(f))

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# margin-top:25px;
# ">
#
# <ul>
#
# <li>Las variables no tienen tipo.</li>
#
# <li>Las variables apuntan a objetos que sí lo tienen.</li>
#
# <li>
# Dado que Python es un lenguaje de tipado dinámico, la misma variable puede apuntar, en momentos diferentes de la ejecución del programa, a objetos de diferente tipo.
# </li>
#
# </ul>
#
# </div>

# %%
# a = 3

# print(a)
# print(type(a))

# a = "Pablo García"

# print(a)
# print(type(a))

# a = 4.5

# print(a)
# print(type(a))

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# margin-top:20px;
# ">
#
# <ul>
#
# <li><b>Garbage collection:</b> Cuando un objeto deja de estar referenciado, se elimina automáticamente.</li>
#
# </ul>
#
# </div>

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:24px;
# font-weight:bold;
# margin-top:35px;
# margin-bottom:20px;
# ">
#
# Identificadores
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Podemos obtener un identificador único para los objetos referenciados por variables.</li>
#
# <li>Este identificador se obtiene a partir de la dirección de memoria.</li>
#
# </ul>
#
# </div>

# %%
a = 3
print(id(a))

a = "Pablo García"
print(id(a))

a = 4.5
print(id(a))
# Out:
# 140714462298984
# 2965582460080
# 2965581854192

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# margin-top:20px;
# ">
#
# <ul>
#
# <li>
# <b>Referencias compartidas:</b> un mismo objeto puede ser referenciado por más de una variable.
# </li>
#
# <li>
# Variables que referencian al mismo objeto tienen el mismo identificador.
# </li>
#
# </ul>
#
# </div>

# %%
a = 4567

print(id(a))
# Out:
# 2965581854832

# %%
b = a

print(id(b))
# Out:
# 2965581854832

# %%
c = 4567

print(id(c))
# Out:
# 2965581855248

# %%
a = 25
b = 25

print(id(a))
print(id(b))
print(id(25))
# Out:
# 140714462299688
# 140714462299688
# 140714462299688

# %%
# Ojo con los enteros "grandes" [-5, 256]

a = 258
b = 258

print(id(a))
print(id(b))
print(id(258))
# Out:
# 2965581856176
# 2965581854928
# 2965581855216

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# margin-top:20px;
# ">
#
# <ul>
#
# <li>Referencia al mismo objeto a través de asignar una variable a otra.</li>
#
# </ul>
#
# </div>

# %%
a = 400
b = a

print(id(a))
print(id(b))
# Out:
# 2965581854640
# 2965581854640

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# margin-top:20px;
# ">
#
# <ul>
#
# <li>Las variables pueden aparecer en expresiones.</li>
#
# </ul>
#
# </div>

# %%
a = 3
b = 5

print(a + b)
# Out:
# 8

# %%
c = a + b

print(c)
print(id(c))
# Out:
# 8
# 140714462299144

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:24px;
# font-weight:bold;
# margin-top:35px;
# margin-bottom:20px;
# ">
#
# Respecto a los nombres de las variables…
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>No se puede poner números delante del nombre de las variables.</li>
#
# <li>Por convención, evitar <b>CamelCase</b>. Mejor usar <b>snake_case</b>: uso de "<code>_</code>" para separar palabras.</li>
#
# <li>El lenguaje diferencia entre mayúsculas y minúsculas.</li>
#
# <li>Deben ser descriptivos.</li>
#
# <li>Hay palabras o métodos reservados (<b>Built-ins</b> y <b>Keywords</b>).</li>
#
# <li>¡Ojo con reasignar un nombre reservado!</li>
#
# </ul>
#
# </div>

# %%
print(pow(3, 2))
# Out:
# 9

# %%
print(pow(3, 2))

pow = 1      # built-in reasignado

print(pow)

print(pow(3, 2))
# Out:
# 9
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 7
#       3 pow = 1      # built-in reasignado
#       4
#       5 print(pow)
#       6
# ----> 7 print(pow(3, 2))
#
# TypeError: 'int' object is not callable

# %%
def pow(a, b):
    return a + b

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:24px;
# font-weight:bold;
# margin-top:35px;
# margin-bottom:20px;
# ">
#
# Asignación múltiple de variables
#
# </div>

# %%
x, y, z = 1, 2, 3

print(x, y, z)

t = x, y, z, 7, "Python"

print(t)

print(type(t))
# Out:
# 1 2 3
# (1, 2, 3, 7, 'Python')
# <class 'tuple'>

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# margin-top:20px;
# ">
#
# <ul>
#
# <li>
# Esta técnica tiene un uso interesante: el intercambio de valores entre dos variables.
# </li>
#
# </ul>
#
# </div>

# %%
a = 1
b = 2

a, b = b, a

print(a, b)
# Out:
# 2 1

# %%
a = 1
b = 2

c = a

a = b

b = c

print(a, b, c)
# Out:
# 2 1 1

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:28px;
# font-weight:bold;
# margin-top:35px;
# margin-bottom:20px;
# ">
#
# 2.3 Tipos de datos básicos
#
# </div>

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:24px;
# font-weight:bold;
# margin-top:25px;
# margin-bottom:15px;
# ">
#
# Bool
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>2 posibles valores: <code>True</code> o <code>False</code>.</li>
#
# </ul>
#
# </div>

# %%
a = False
b = True

print(a)
print(type(a))

print(b)
print(type(b))
# Out:
# False
# <class 'bool'>
# True
# <class 'bool'>

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li><code>True</code> y <code>False</code> también son objetos que se guardan en caché, al igual que los enteros pequeños.</li>
#
# </ul>
#
# </div>

# %%
a = True
b = True

print(id(a))
print(id(b))

print(a is b)

print(a == b)
# Out:
# 140714460822080
# 140714460822080
# True
# True

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:24px;
# font-weight:bold;
# margin-top:30px;
# margin-bottom:15px;
# ">
#
# Números
#
# </div>

# %%
print(2)        # Enteros, sin parte fraccional.

print(3.4)      # Números en coma flotante, con parte fraccional.

print(2 + 4j)   # Números complejos.

print(1 / 2)    # Números racionales.
# Out:
# 2
# 3.4
# (2+4j)
# 0.5

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Diferentes representaciones: base 10, 2, 8 y 16.</li>
#
# </ul>
#
# </div>

# %%
x = 58          # Decimal

z = 0b00111010  # Binario

w = 0o72        # Octal

y = 0x3A        # Hexadecimal

print(x == y == z == w)
# Out:
# True

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:24px;
# font-weight:bold;
# margin-top:30px;
# margin-bottom:15px;
# ">
#
# Strings
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Cadenas de caracteres.</li>
#
# <li>Son secuencias: la posición de los caracteres es importante.</li>
#
# <li>Son <b>inmutables</b>: las operaciones sobre strings no cambian el string original.</li>
#
# </ul>
#
# </div>

# %%
s = 'John "ee" Doe'

print(s[0])        # Primer carácter.

print(s[-1])       # Último carácter.

print(s[1:8:2])    # Slicing.

print(s[:])        # Todo el string.

print(s + "e")     # Concatenación.
# Out:
# J
# e
# on"e
# John "ee" Doe
# John "ee" Doee

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:28px;
# font-weight:bold;
# margin-top:35px;
# margin-bottom:20px;
# ">
#
# 2.4 Conversión entre tipos
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>A veces queremos que un objeto sea de un tipo específico.</li>
#
# <li>Podemos obtener objetos de un tipo a partir de objetos de un tipo diferente (<i>casting</i>).</li>
#
# </ul>
#
# </div>

# %%
a = int(2.8)          # a será 2
b = int("3")          # b será 3

c = float(1)          # c será 1.0
d = float("3")        # d será 3.0

e = str(2)            # e será "2"
f = str(3.0)          # f será "3.0"

g = bool("a")         # g será True
h = bool("")          # h será False

i = bool(3)           # i será True
j = bool(0)           # j será False

k = bool(None)

print(a)
print(type(a))

print(b)
print(type(b))

print(c)
print(type(c))

print(d)
print(type(d))

print(e)
print(type(e))

print(f)
print(type(f))

print(g)
print(type(g))

print(h)
print(type(h))

print(i)
print(type(i))

print(j)
print(type(j))

print(k)
# Out:
# 2
# <class 'int'>
# 3
# <class 'int'>
# 1.0
# <class 'float'>
# 3.0
# <class 'float'>
# 2
# <class 'str'>
# 3.0
# <class 'str'>
# True
# <class 'bool'>
# False
# <class 'bool'>
# True
# <class 'bool'>
# False
# <class 'bool'>
# False

# %%
print(7 / 4)       # División convencional. Resultado de tipo float.

print(7 // 4)      # División entera. Resultado de tipo int.

print(int(7 / 4))  # Conversión del resultado de float a int.
# Out:
# 1.75
# 1
# 1

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:28px;
# font-weight:bold;
# margin-top:35px;
# margin-bottom:20px;
# ">
#
# 2.5 Operadores
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <b>Python 3: precedencia en operaciones</b>
#
# <ul>
#
# <li>Combinación de valores, variables y operadores.</li>
#
# <li>Operadores y operandos.</li>
#
# </ul>
#
# </div>

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:22px;
# font-weight:bold;
# margin-top:25px;
# margin-bottom:15px;
# ">
#
# Operadores aritméticos
#
# </div>
#
# <table style="
# border-collapse:collapse;
# font-family:'Times New Roman', serif;
# font-size:18px;
# width:60%;
# ">
#
# <tr style="background:#f2f2f2;">
# <th style="border:1px solid black;padding:8px;">Operador</th>
# <th style="border:1px solid black;padding:8px;">Descripción</th>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a + b</code></td>
# <td style="border:1px solid black;padding:8px;">Suma</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a - b</code></td>
# <td style="border:1px solid black;padding:8px;">Resta</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a / b</code></td>
# <td style="border:1px solid black;padding:8px;">División</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a // b</code></td>
# <td style="border:1px solid black;padding:8px;">División entera</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a % b</code></td>
# <td style="border:1px solid black;padding:8px;">Módulo / Resto</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a * b</code></td>
# <td style="border:1px solid black;padding:8px;">Multiplicación</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a ** b</code></td>
# <td style="border:1px solid black;padding:8px;">Exponenciación</td>
# </tr>
#
# </table>

# %%
x = 3
y = 2

print("x + y =", x + y)
print("x - y =", x - y)
print("x * y =", x * y)
print("x / y =", x / y)
print("x // y =", x // y)
print("x % y =", x % y)
print("x ** y =", x ** y)
# Out:
# x + y = 5
# x - y = 1
# x * y = 6
# x / y = 1.5
# x // y = 1
# x % y = 1
# x ** y = 9

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:22px;
# font-weight:bold;
# margin-top:30px;
# margin-bottom:15px;
# ">
#
# Operadores de comparación
#
# </div>
#
# <table style="
# border-collapse:collapse;
# font-family:'Times New Roman', serif;
# font-size:18px;
# width:60%;
# ">
#
# <tr style="background:#f2f2f2;">
# <th style="border:1px solid black;padding:8px;">Operador</th>
# <th style="border:1px solid black;padding:8px;">Descripción</th>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a &gt; b</code></td>
# <td style="border:1px solid black;padding:8px;">Mayor</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a &lt; b</code></td>
# <td style="border:1px solid black;padding:8px;">Menor</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a == b</code></td>
# <td style="border:1px solid black;padding:8px;">Igualdad</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a != b</code></td>
# <td style="border:1px solid black;padding:8px;">Desigualdad</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a &gt;= b</code></td>
# <td style="border:1px solid black;padding:8px;">Mayor o igual</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a &lt;= b</code></td>
# <td style="border:1px solid black;padding:8px;">Menor o igual</td>
# </tr>
#
# </table>

# %%
x = 10
y = 12

print("x > y es", x > y)
print("x < y es", x < y)
print("x == y es", x == y)
print("x != y es", x != y)
print("x >= y es", x >= y)
print("x <= y es", x <= y)
# Out:
# x > y es False
# x < y es True
# x == y es False
# x != y es True
# x >= y es False
# x <= y es True

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:22px;
# font-weight:bold;
# margin-top:30px;
# margin-bottom:15px;
# ">
#
# Operadores lógicos
#
# </div>
#
# <table style="
# border-collapse:collapse;
# font-family:'Times New Roman', serif;
# font-size:18px;
# width:70%;
# ">
#
# <tr style="background:#f2f2f2;">
# <th style="border:1px solid black;padding:8px;">Operador</th>
# <th style="border:1px solid black;padding:8px;">Descripción</th>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a and b</code></td>
# <td style="border:1px solid black;padding:8px;">True, si ambos son True.</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a or b</code></td>
# <td style="border:1px solid black;padding:8px;">True, si alguno de los dos es True.</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a ^ b</code></td>
# <td style="border:1px solid black;padding:8px;">XOR. True, si solo uno de los dos es True.</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>not a</code></td>
# <td style="border:1px solid black;padding:8px;">Negación.</td>
# </tr>
#
# </table>
#
# <br>
#
# <a href="https://es.wikipedia.org/wiki/Tabla_de_verdad" target="_blank">
# Enlace a Tablas de Verdad
# </a>
#
# </div>

# %%
x = True
y = False

print("x and y es :", x and y)
print("x or y es :", x or y)
print("x xor y es :", x ^ y)
print("not x es :", not x)
# Out:
# x and y es : False
# x or y es : True
# x xor y es : True
# not x es : False

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:22px;
# font-weight:bold;
# margin-top:30px;
# margin-bottom:15px;
# ">
#
# Operadores Bitwise / Binarios
#
# </div>
#
# <table style="
# border-collapse:collapse;
# font-family:'Times New Roman', serif;
# font-size:18px;
# width:70%;
# ">
#
# <tr style="background:#f2f2f2;">
# <th style="border:1px solid black;padding:8px;">Operador</th>
# <th style="border:1px solid black;padding:8px;">Descripción</th>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a &amp; b</code></td>
# <td style="border:1px solid black;padding:8px;">And binario</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a | b</code></td>
# <td style="border:1px solid black;padding:8px;">Or binario</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a ^ b</code></td>
# <td style="border:1px solid black;padding:8px;">Xor binario</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>~a</code></td>
# <td style="border:1px solid black;padding:8px;">Not binario</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a >> b</code></td>
# <td style="border:1px solid black;padding:8px;">Desplazamiento binario a la derecha</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a << b</code></td>
# <td style="border:1px solid black;padding:8px;">Desplazamiento binario a la izquierda</td>
# </tr>
#
# </table>

# %%
# x = 0b01100110
# y = 0b00110011

# print("Not x = " + bin(~x))

# print("x and y = " + bin(x & y))

# print("x or y = " + bin(x | y))

# print("x xor y = " + bin(x ^ y))

# print("x << 2 = " + bin(x << 2))

# print("x >> 2 = " + bin(x >> 2))

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:22px;
# font-weight:bold;
# margin-top:30px;
# margin-bottom:15px;
# ">
#
# Operadores de asignación
#
# </div>
#
# <table style="
# border-collapse:collapse;
# font-family:'Times New Roman', serif;
# font-size:18px;
# width:70%;
# ">
#
# <tr style="background:#f2f2f2;">
# <th style="border:1px solid black;padding:8px;">Operador</th>
# <th style="border:1px solid black;padding:8px;">Descripción</th>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>=</code></td>
# <td style="border:1px solid black;padding:8px;">Asignación</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>+=</code></td>
# <td style="border:1px solid black;padding:8px;">Suma y asignación</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>-=</code></td>
# <td style="border:1px solid black;padding:8px;">Resta y asignación</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>*=</code></td>
# <td style="border:1px solid black;padding:8px;">Multiplicación y asignación</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>/=</code></td>
# <td style="border:1px solid black;padding:8px;">División y asignación</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>%=</code></td>
# <td style="border:1px solid black;padding:8px;">Módulo y asignación</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>//=</code></td>
# <td style="border:1px solid black;padding:8px;">División entera y asignación</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>**=</code></td>
# <td style="border:1px solid black;padding:8px;">Exponenciación y asignación</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>&amp;=</code></td>
# <td style="border:1px solid black;padding:8px;">And y asignación</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>|=</code></td>
# <td style="border:1px solid black;padding:8px;">Or y asignación</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>^=</code></td>
# <td style="border:1px solid black;padding:8px;">Xor y asignación</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>>>=</code></td>
# <td style="border:1px solid black;padding:8px;">Desplazamiento a la derecha y asignación</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code><<=</code></td>
# <td style="border:1px solid black;padding:8px;">Desplazamiento a la izquierda y asignación</td>
# </tr>
#
# </table>

# %%
a = 5

a *= 3          # a = a * 3

a += 1          # No existe a++, ni ++a, a--, --a

print(a)

b = 6

b -= 2          # b = b - 2

print(b)
# Out:
# 16
# 4

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:22px;
# font-weight:bold;
# margin-top:30px;
# margin-bottom:15px;
# ">
#
# Operadores de identidad
#
# </div>
#
# <table style="
# border-collapse:collapse;
# font-family:'Times New Roman', serif;
# font-size:18px;
# width:70%;
# ">
#
# <tr style="background:#f2f2f2;">
# <th style="border:1px solid black;padding:8px;">Operador</th>
# <th style="border:1px solid black;padding:8px;">Descripción</th>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a is b</code></td>
# <td style="border:1px solid black;padding:8px;">True, si ambos operandos son una referencia al mismo objeto.</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a is not b</code></td>
# <td style="border:1px solid black;padding:8px;">True, si ambos operandos no son una referencia al mismo objeto.</td>
# </tr>
#
# </table>

# %%
a = 4444
b = a

print(a is b)
print(a is not b)
# Out:
# True
# False

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:22px;
# font-weight:bold;
# margin-top:30px;
# margin-bottom:15px;
# ">
#
# Operadores de pertenencia
#
# </div>
#
# <table style="
# border-collapse:collapse;
# font-family:'Times New Roman', serif;
# font-size:18px;
# width:70%;
# ">
#
# <tr style="background:#f2f2f2;">
# <th style="border:1px solid black;padding:8px;">Operador</th>
# <th style="border:1px solid black;padding:8px;">Descripción</th>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a in b</code></td>
# <td style="border:1px solid black;padding:8px;">True, si <b>a</b> se encuentra en la secuencia <b>b</b>.</td>
# </tr>
#
# <tr>
# <td style="border:1px solid black;padding:8px;"><code>a not in b</code></td>
# <td style="border:1px solid black;padding:8px;">True, si <b>a</b> no se encuentra en la secuencia <b>b</b>.</td>
# </tr>
#
# </table>

# %%
x = "Hola Mundo"
y = {1: "a", 2: "b"}

print("H" in x)          # True

print("hola" not in x)   # True

print(1 in y)            # True

print("a" in y)          # False
# Out:
# True
# True
# True
# False

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:28px;
# font-weight:bold;
# margin-top:35px;
# margin-bottom:20px;
# ">
#
# 2.6 Entrada de valores
#
# </div>

# %%
valor = input("Inserte valor: ")

print(valor)

print(type(valor))
# Out:
# Inserte valor:  true
# true
# <class 'str'>

# %%
grados_c = int(input("Conversión de grados a Fahrenheit, inserte un valor: "))

print(f"Grados F: {1.8 * grados_c + 32}")
# Out:
# Conversión de grados a Fahrenheit, inserte un valor:  8
# Grados F: 46.4

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:32px;
# font-weight:bold;
# margin-top:45px;
# margin-bottom:20px;
# ">
#
# 3 Tipos de datos compuestos (colecciones)
#
# </div>

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:28px;
# font-weight:bold;
# margin-top:25px;
# margin-bottom:15px;
# ">
#
# 3.1 Listas
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Una colección de objetos.</li>
#
# <li>Mutables.</li>
#
# <li>Tipos arbitrarios heterogéneos.</li>
#
# <li>Puede contener duplicados.</li>
#
# <li>No tienen tamaño fijo. Pueden contener tantos elementos como quepan en memoria.</li>
#
# <li>Los elementos van ordenados por posición.</li>
#
# <li>Se acceden usando la sintaxis: <code>[index]</code>.</li>
#
# <li>Los índices van de <code>0</code> a <code>n-1</code>, donde <code>n</code> es el número de elementos de la lista.</li>
#
# <li>Son un tipo de <b>Secuencia</b>, al igual que los strings; por lo tanto, el orden (es decir, la posición de los objetos de la lista) es importante.</li>
#
# <li>Soportan anidamiento.</li>
#
# <li>Son una implementación del tipo abstracto de datos: <b>Array Dinámico</b>.</li>
#
# </ul>
#
# </div>

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:22px;
# font-weight:bold;
# margin-top:30px;
# margin-bottom:15px;
# ">
#
# Operaciones con listas
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Creación de listas.</li>
#
# </ul>
#
# </div>

# %%
letras = ['a', 'b', 'c', 'd']

palabras = "Hola mundo como estas".split()

numeros = list(range(7))

print(letras)

print(palabras)

print(numeros)

print(type(numeros))
# Out:
# ['a', 'b', 'c', 'd']
# ['Hola', 'mundo', 'como', 'estas']
# [0, 1, 2, 3, 4, 5, 6]
# <class 'list'>

# %%
# Pueden contener elementos arbitrarios / heterogéneos

mezcla = [1, 3.4, "a", None, False]

print(mezcla)

print(len(mezcla))    # Número de elementos de la lista
# Out:
# [1, 3.4, 'a', None, False]
# 5

# %%
# Pueden incluso contener objetos más "complejos"

lista_con_funcion = [1, 2, len, pow]

print(lista_con_funcion)
# Out:
# [1, 2, <built-in function len>, <function pow at 0x000002B27A8F0B80>]

# %%
# Pueden contener duplicados

lista_con_duplicados = [1, 2, 3, 3, 3, 4]

print(lista_con_duplicados)
# Out:
# [1, 2, 3, 3, 3, 4]

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Obtención de la longitud de una lista.</li>
#
# </ul>
#
# </div>

# %%
letras = ["a", "b", "c", "d", 1]

print(len(letras))
# Out:
# 5

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Acceso a un elemento de una lista.</li>
#
# </ul>
#
# </div>

# %%
print(letras[2])

print(letras[-5])

print(letras[0])
# Out:
# c
# a
# a

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li><b>Slicing:</b> obtención de un fragmento de una lista. Devuelve una copia de una parte de la lista.</li>
#
# <ul>
#
# <li>Sintaxis: <code>lista[inicio:fin:paso]</code></li>
#
# </ul>
#
# </ul>
#
# </div>

# %%
letras = ["a", "b", "c", "d", "e"]

print(letras[1:3])

print(letras[:3])

print(letras[:-1])

print(letras[2:])

print(letras[:])

print(letras[::2])
# Out:
# ['b', 'c']
# ['a', 'b', 'c']
# ['a', 'b', 'c', 'd']
# ['c', 'd', 'e']
# ['a', 'b', 'c', 'd', 'e']
# ['a', 'c', 'e']

# %%
letras = ["a", "b", "c", "d"]

print(letras)

print(id(letras))

a = letras[:]

print(a)

print(id(a))

print(letras.copy())

print(id(letras.copy()))
# Out:
# ['a', 'b', 'c', 'd']
# 2965582661824
# ['a', 'b', 'c', 'd']
# 2965582805696
# ['a', 'b', 'c', 'd']
# 2965582988608

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Añadir un elemento al final de la lista.</li>
#
# </ul>
#
# </div>

# %%
letras.append("e")

print(letras)

print(id(letras))
# Out:
# ['a', 'b', 'c', 'd', 'e']
# 2965582661824

# %%
letras += "e"

print(letras)

print(id(letras))
# Out:
# ['a', 'b', 'c', 'd', 'e', 'e']
# 2965582661824

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Insertar en una posición.</li>
#
# </ul>
#
# </div>

# %%
print(len(letras))

letras.insert(1, "g")

print(len(letras))

print(letras)

print(id(letras))
# Out:
# 6
# 7
# ['a', 'g', 'b', 'c', 'd', 'e', 'e']
# 2965582661824

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Modificación de la lista (individual).</li>
#
# </ul>
#
# </div>

# %%
letras[5] = "f"

print(letras)

print(id(letras))
# Out:
# ['a', 'g', 'b', 'c', 'd', 'f', 'e']
# 2965582661824

# %%
# El índice debe estar dentro del rango de la lista

letras[20] = "r"
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[58], line 3
#       1 # El índice debe estar dentro del rango de la lista
#       2
# ----> 3 letras[20] = "r"
#
# IndexError: list assignment index out of range

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Modificación múltiple usando <b>slicing</b>.</li>
#
# </ul>
#
# </div>

# %%
letras = ["a", "b", "c", "f", "g", "h", "i", "j", "k"]

print(id(letras))
# Out:
# 2965582665088

# %%
letras[0:7:2] = ["z", "x", "y", "p"]

print(letras)

# print(id(letras))
# Out:
# ['z', 'b', 'x', 'f', 'y', 'h', 'p', 'j', 'k']

# %%
# Ojo con la diferencia entre modificación individual y múltiple.
# La asignación individual de una lista crea anidamiento.

numeros = [1, 2, 3]

numeros[1] = [10, 20, 30]

print(numeros)

print(numeros[1][0])

numeros[1][2] = [100, 200]

print(numeros)

print(numeros[1][2][1])
# Out:
# [1, [10, 20, 30], 3]
# 10
# [1, [10, 20, [100, 200]], 3]
# 200

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Eliminar un elemento.</li>
#
# </ul>
#
# </div>

# %%
# letras.remove("f")

if "p" in letras:
    letras.remove("p")

# letras.remove("z")

print(letras)
# Out:
# ['z', 'b', 'x', 'f', 'y', 'h', 'j', 'k']

# %%
# Elimina el elemento de la última posición y lo devuelve

elemento = letras.pop()

print(elemento)

print(letras)
# Out:
# k
# ['z', 'b', 'x', 'f', 'y', 'h', 'j']

# %%
numeros = [1, 2, 3]

print(numeros)

numeros[2] = [10, 20, 30]
# Out:
# [1, 2, 3]

# %%
print(numeros)

n = numeros[2].pop()

print(numeros)

print(n)
# Out:
# [1, 2, [10, 20, 30]]
# [1, 2, [10, 20]]
# 30

# %%
# numeros1 = 10

# print(numeros1)

# print(numeros)

# %%
lista = []

a = lista.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[67], line 3
#       1 lista = []
#       2
# ----> 3 a = lista.pop()
#
# IndexError: pop from empty list

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Encontrar el índice de un elemento.</li>
#
# </ul>
#
# </div>

# %%
letras = ["a", "b", "c", "c"]

if "a" in letras:
    print(letras.index("a"))

print(letras)
# Out:
# 0
# ['a', 'b', 'c', 'c']

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Concatenar listas.</li>
#
# </ul>
#
# </div>

# %%
lacteos = ["queso", "leche"]

frutas = ["naranja", "manzana"]

print(id(lacteos))

print(id(frutas))

compra = lacteos + frutas

print(id(compra))

print(compra)
# Out:
# 2965582965504
# 2965582954880
# 2965583957440
# ['queso', 'leche', 'naranja', 'manzana']

# %%
# Concatenación sin crear una nueva lista

frutas = ["naranja", "manzana"]

print(id(frutas))

frutas.extend(["pera", "uvas"])

print(frutas)

print(id(frutas))
# Out:
# 2965582839744
# ['naranja', 'manzana', 'pera', 'uvas']
# 2965582839744

# %%
# Anidar sin crear una nueva lista

frutas = ["naranja", "manzana"]

print(id(frutas))

frutas.append(["pera", "uvas"])

print(frutas)

print(id(frutas))
# Out:
# 2965582954880
# ['naranja', 'manzana', ['pera', 'uvas']]
# 2965582954880

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Replicar una lista.</li>
#
# </ul>
#
# </div>

# %%
lacteos = ["queso", "leche"]

print(lacteos * 3)

print(id(lacteos))

a = 3 * lacteos

print(a)

print(id(a))
# Out:
# ['queso', 'leche', 'queso', 'leche', 'queso', 'leche']
# 2965582990976
# ['queso', 'leche', 'queso', 'leche', 'queso', 'leche']
# 2965583735104

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Copiar una lista.</li>
#
# </ul>
#
# </div>

# %%
frutas2 = frutas.copy()

frutas2 = frutas[:]

print(frutas2)

print("id frutas = " + str(id(frutas)))

print("id frutas2 = " + str(id(frutas2)))
# Out:
# ['naranja', 'manzana', ['pera', 'uvas']]
# id frutas = 2965582954880
# id frutas2 = 2965582961984

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Ordenar una lista.</li>
#
# </ul>
#
# </div>

# %%
lista = [4, 3, 8, 1]

print(lista)

lista.sort()

print(lista)

lista.sort(reverse=True)

print(lista)
# Out:
# [4, 3, 8, 1]
# [1, 3, 4, 8]
# [8, 4, 3, 1]

# %%
# Los elementos deben ser comparables para poder ordenarse

lista = [1, "a"]

lista.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 5
#       1 # Los elementos deben ser comparables para poder ordenarse
#       2
#       3 lista = [1, "a"]
#       4
# ----> 5 lista.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
compra = ["Huevos", "Pan", "zapallo", "Leche", "Licor"]

print(sorted(compra))

print(compra)
# Out:
# ['Huevos', 'Leche', 'Licor', 'Pan', 'zapallo']
# ['Huevos', 'Pan', 'zapallo', 'Leche', 'Licor']

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Pertenencia.</li>
#
# </ul>
#
# </div>

# %%
lista = [1, 2, 3, 4]

print(1 in lista)

print(5 in lista)
# Out:
# True
# False

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Anidamiento.</li>
#
# </ul>
#
# </div>

# %%
letras = ["a", "b", "c", ["x", "y", ["i", "j", "k"]]]

print(letras[0])

print(letras[3][0])

print(letras[3][2][0])
# Out:
# a
# x
# i

# %%
print(letras[3])
# Out:
# ['x', 'y', ['i', 'j', 'k']]

# %%
a = [1000, 2, 3]

b = a[:]          # También puede usarse a.copy()

print(id(a))

print(id(b))

print(id(a[0]))

print(id(b[0]))
# Out:
# 2965582841792
# 2965582852160
# 2965583824720
# 2965583824720

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:22px;
# font-weight:bold;
# margin-top:30px;
# margin-bottom:15px;
# ">
#
# Alias / Referencias en las listas
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Las listas son <b>mutables</b> y las asignaciones modifican el mismo objeto.</li>
#
# <li>Pasar listas como parámetros a funciones puede implicar riesgos si se modifican.</li>
#
# <li>Cuando se desea trabajar con una copia independiente, es recomendable clonar o copiar la lista.</li>
#
# </ul>
#
# </div>

# %%
lista = [2, 4, 16, 32]

ref = lista

print(id(lista))

print(id(ref))

ref[2] = 64

print(ref)

print(lista)
# Out:
# 2965557094784
# 2965557094784
# [2, 4, 64, 32]
# [2, 4, 64, 32]

# %%
lista = [2000, 4, 16, 32]

copia = lista[:]

copia = lista.copy()

copia[2] = 64

print(lista)

print(copia)

print(id(lista))

print(id(copia))

print(id(lista[2]))

print(id(copia[2]))
# Out:
# [2000, 4, 16, 32]
# [2000, 4, 64, 32]
# 2965582738688
# 2965582906112
# 140714462299400
# 140714462300936

# %%
# Las listas anidadas se copian por referencia (copia superficial)

lista = [2, 4, 16, 32, [34, 10, [5, 5]]]

copia = lista.copy()

copia[3] = 20

copia[4][0] = 28

print(copia)

print(lista)
# Out:
# [2, 4, 16, 20, [28, 10, [5, 5]]]
# [2, 4, 16, 32, [28, 10, [5, 5]]]

# %%
# lista = [0, 1, [10, 20]]

# print(id(lista))

# lista2 = [10, 20]

# lista = [0, 1, lista2]

# copia = lista[:]      # También puede usarse lista.copy()

# print(copia)

# print(id(copia))

# print(id(lista[2]))

# print(id(copia[2]))

# copia[2][0] = 40

# print(copia)

# print(lista)

# %%
# Evitar que listas anidadas se copien por referencia

# import copy

# lista = [2, 4, 16, 32, [34, 10, [5, 5]]]

# copia = copy.deepcopy(lista)

# copia[0] = 454

# copia[4][2][0] = 64

# print(lista)

# print(copia)

# print(f"{id(lista)} - {id(copia)}")

# print(f"{id(lista[4])} - {id(copia[4])}")

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:30px;
# font-weight:bold;
# margin-top:35px;
# margin-bottom:20px;
# ">
#
# 3.2 Diccionarios
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Colección de parejas <b>clave-valor</b>.</li>
#
# <li>Son <b>mutables</b>.</li>
#
# <li><b>Claves:</b>
#     <ul>
#         <li>Cualquier objeto inmutable.</li>
#         <li>Sólo pueden aparecer una vez en el diccionario.</li>
#     </ul>
# </li>
#
# <li><b>Valores:</b>
#     <ul>
#         <li>Sin restricciones. Cualquier objeto (enteros, strings, listas, etc.) puede hacer de valor.</li>
#     </ul>
# </li>
#
# <li>Desde la versión <b>3.7</b> están ordenados.</li>
#
# <li>Se pueden ver como listas indexadas por cualquier objeto inmutable, no necesariamente por números enteros.</li>
#
# <li>A diferencia de las listas, no son secuencias. Son <b>mappings</b>.</li>
#
# </ul>
#
# </div>

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:22px;
# font-weight:bold;
# margin-top:25px;
# margin-bottom:15px;
# ">
#
# Operaciones con diccionarios
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Creación de diccionarios.</li>
#
# </ul>
#
# </div>

# %%
# Creación simple usando una expresión literal.

persona = {
    "DNI": "11111111D",
    "Nombre": "Carlos",
    "Edad": 34
}

print(persona)
# Out:
# {'DNI': '11111111D', 'Nombre': 'Carlos', 'Edad': 34}

# %%
# Creación uniendo dos colecciones.

nombres = ["Pablo", "Manolo", "Pepe", "Juan"]

edades = [52, 14, 65]

datos = dict(zip(nombres, edades))

print(datos)
# Out:
# {'Pablo': 52, 'Manolo': 14, 'Pepe': 65}

# %%
# Creación pasando claves y valores a la función dict()

persona2 = dict(
    nombre="Rosa",
    apellido="Garcia"
)

print(persona2)
# Out:
# {'nombre': 'Rosa', 'apellido': 'Garcia'}

# %%
# Creación usando una lista de tuplas de dos elementos.

persona2 = dict([
    ("nombre", "Rosa"),
    ("apellido", "Garcia")
])

print(persona2)
# Out:
# {'nombre': 'Rosa', 'apellido': 'Garcia'}

# %%
# Creación incremental por medio de asignación
# (como las claves no existen, se crean nuevos items)

persona = {}

print(persona["DNI"])

persona["DNI"] = "11111111D"

persona["Nombre"] = "Carlos"

persona["Edad"] = 34

persona["DNI"] = "222222222"

print(persona)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[90], line 6
#       2 # (como las claves no existen, se crean nuevos items)
#       3
#       4 persona = {}
#       5
# ----> 6 print(persona["DNI"])
#       7
#       8 persona["DNI"] = "11111111D"
#       9
#
# KeyError: 'DNI'

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Acceso a un valor a través de la clave.</li>
#
# </ul>
#
# </div>

# %%
persona = {
    "DNI": "11111111D",
    "Nombre": "Carlos",
    "Edad": 34
}

print(persona["Nombre"])
# Out:
# Carlos

# %%
# Acceso a claves inexistentes o por índice produce error

# persona[1]

# print(persona["Nombre"])

# if "Trabajo" in persona:
#     print(persona["Trabajo"])
# else:
#     print("En el paro")

# persona.get("Trabajo", "En el paro")

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Modificación de un valor a través de la clave.</li>
#
# </ul>
#
# </div>

# %%
# persona = {
#     "DNI": "11111111D",
#     "Nombre": "Carlos",
#     "Edad": 34
# }

# persona["Nombre"] = "Fernando"

# persona["Edad"] += 1

# print(persona)

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Añadir un valor a través de la clave.</li>
#
# </ul>
#
# </div>

# %%
# persona = {
#     "DNI": "11111111D",
#     "Nombre": "Carlos",
#     "Edad": 34
# }

# persona["Ciudad"] = "Valencia"

# print(persona)

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Eliminación de un valor a través de la clave.</li>
#
# </ul>
#
# </div>

# %%
# del persona["Ciudad"]

# value = persona.pop("Edad")

# print(persona)

# print(value)

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Comprobación de existencia de una clave.</li>
#
# </ul>
#
# </div>

# %%
# print("Nombre" in persona)

# print("Apellido" in persona)

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Recuperación del valor de una clave, indicando un valor por defecto en caso de ausencia.</li>
#
# </ul>
#
# </div>

# %%
# persona = {"Nombre": "Carlos"}

# value = persona.get("Nombre")

# print(value)

# persona["Estatura"]

# value = persona.get("Estatura", 180)

# print(value)

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Anidamiento.</li>
#
# </ul>
#
# </div>

# %%
# persona = {
#     "Trabajos": ["desarrollador", "gestor"],
#     "Direccion": {
#         "Calle": "Pintor Sorolla",
#         "Ciudad": "Valencia"
#     }
# }

# print(persona["Direccion"])

# print(persona["Direccion"]["Ciudad"])

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Métodos <code>items()</code>, <code>keys()</code> y <code>values()</code>.</li>
#
# </ul>
#
# </div>

# %%
# persona = {
#     "DNI": "11111111D",
#     "Nombre": "Carlos",
#     "Edad": 34
# }

# print(list(persona.items()))

# print(list(persona.keys()))

# print(list(persona.values()))

# %%
# dict_simple = {
#     "ID": "XCSDe1194",
#     "Nombre": "Carlos",
#     "Edad": 34
# }

# Iterar sobre las claves

# print("Claves\n")

# for key in dict_simple.keys():      # o simplemente: for key in dict_simple:
#     print(key)

# print("\nValores\n")

# Iterar sobre los valores

# for value in dict_simple.values():
#     print(value)

# %%
# dict_simple = {
#     "ID": "XCSDe1194",
#     "Nombre": "Carlos",
#     "Edad": 34
# }

# Iterar sobre clave y valor usando items()

# for key, value in dict_simple.items():
#     print("Clave: " + str(key) + ", valor: " + str(value))

# items() devuelve tuplas

# for item in dict_simple.items():
#     print("Item: " + str(item))

# Usar zip() para recorrer claves y valores

# for key, value in zip(dict_simple.keys(), dict_simple.values()):
#     print("Clave: " + str(key) + ", valor: " + str(value))

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:30px;
# font-weight:bold;
# margin-top:35px;
# margin-bottom:20px;
# ">
#
# 3.3 Sets (Conjuntos)
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# Al igual que las listas:
#
# <ul>
#
# <li>Colección de elementos.</li>
#
# <li>Tipos arbitrarios.</li>
#
# <li>Mutables.</li>
#
# <li>No tienen tamaño fijo. Pueden contener tantos elementos como quepan en memoria.</li>
#
# </ul>
#
# A diferencia de las listas:
#
# <ul>
#
# <li>No pueden tener elementos duplicados.</li>
#
# <li>Se definen por medio de llaves <code>{ }</code>.</li>
#
# <li>Los elementos no van ordenados por posición. No existe un orden establecido.</li>
#
# <li>Solo pueden contener objetos inmutables.</li>
#
# <li>No soportan anidamiento.</li>
#
# </ul>
#
# </div>

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:22px;
# font-weight:bold;
# margin-top:25px;
# margin-bottom:15px;
# ">
#
# Operaciones con conjuntos
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Creación de conjuntos.</li>
#
# </ul>
#
# </div>

# %%
# set1 = {0, 1, 1, 2, 3, 4, 4}

# print(set1)

# set2 = {"user1", 12, 2}

# print(set2)

# set3 = set(range(7))

# print(set3)

# set4 = set([0, 1, 2, 3, 4, 0, 1])

# print(set4)

# %%
# Observa la diferencia entre listas y conjuntos

# s = "aabbc"

# print(list(s))

# print(set(s))

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Acceso por índice genera error.</li>
#
# </ul>
#
# </div>

# %%
# set1 = {0, 1, 2}

# print(set1[0])

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Unión, intersección y diferencia.</li>
#
# </ul>
#
# </div>

# %%
# set1 = {0, 1, 1, 2, 3, 4, 5, 8, 13, 21}

# set2 = set([0, 1, 2, 3, 4, 42])

# Unión
# print(set1 | set2)

# Intersección
# print(set1 & set2)

# Diferencia
# print(set1 - set2)

# print(set2 - set1)

# %%
# a = [1, 2]

# b = [2, 3]

# print(set(a) & set(b))

# %%
# Además de los operadores, que operan únicamente con Sets,
# también se pueden usar métodos que operan sobre cualquier
# objeto iterable.

# conjunto = {0, 1, 2}

# lista = [1, 3, 3]

# print(conjunto.union(lista))

# print(conjunto.intersection(lista))

# print(conjunto.difference(lista))

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Comparación de conjuntos.</li>
#
# </ul>
#
# </div>

# %%
# set1 = {0, 1, 1, 2, 3, 4, 5, 8, 13, 21}

# set2 = set([0, 1, 2, 3, 4])

# print(set2.issubset(set1))

# print(set1.issuperset(set2))

# print(set1.isdisjoint(set2))

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Pertenencia.</li>
#
# </ul>
#
# </div>

# %%
# words = {"calm", "balm"}

# print("calm" in words)

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Anidamiento.</li>
#
# </ul>
#
# </div>

# %%
# Los conjuntos no soportan anidamiento, pero como permiten
# elementos inmutables, se pueden "anidar" tuplas.

# nested_set = {1, (1, 1, 1), 2, 3, (1, 1, 1)}

# print(nested_set)

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Modificación de conjuntos.</li>
#
# </ul>
#
# </div>

# %%
# A través del operador de asignación

# set1 = {"a", "b", "c"}

# set2 = {"a", "d"}

# set1 |= set2          # set1 = set1 | set2

# set1 &= set2

# set1 -= set2

# print(set1)

# %%
# A través del método update()

# set1 = {"a", "b", "c"}

# set2 = {"a", "d"}

# set1.update(set2)

# set1.intersection_update(set2)

# set1.difference_update(set2)

# print(set1)

# %%
# A través de los métodos add() y remove()

# set1 = {"a", "b", "c"}

# set1.add("d")

# set1.remove("a")

# print(set1)

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:30px;
# font-weight:bold;
# margin-top:35px;
# margin-bottom:20px;
# ">
#
# 3.4 Tuplas
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# Al igual que las listas:
#
# <ul>
#
# <li>Colección de elementos.</li>
#
# <li>Tipos arbitrarios.</li>
#
# <li>Puede contener duplicados.</li>
#
# <li>No tienen tamaño fijo. Pueden contener tantos elementos como quepan en memoria.</li>
#
# <li>Los elementos van ordenados por posición.</li>
#
# <li>Acceso mediante la sintaxis <code>[index]</code>.</li>
#
# <li>Los índices van desde <b>0</b> hasta <b>n-1</b>, donde <b>n</b> es el número de elementos de la tupla.</li>
#
# <li>Son secuencias donde el orden de los elementos importa.</li>
#
# <li>Soportan anidamiento.</li>
#
# </ul>
#
# A diferencia de las listas:
#
# <ul>
#
# <li>Se definen mediante paréntesis <code>( )</code>.</li>
#
# <li>Son <b>inmutables</b>.</li>
#
# </ul>
#
# </div>

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:22px;
# font-weight:bold;
# margin-top:25px;
# margin-bottom:15px;
# ">
#
# ¿Por qué tuplas?
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Representación de una colección fija de elementos (por ejemplo, una fecha).</li>
#
# <li>Pueden usarse en contextos que requieren inmutabilidad (por ejemplo, como claves de un
# diccionario).</li>
#
# </ul>
#
# </div>

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:22px;
# font-weight:bold;
# margin-top:25px;
# margin-bottom:15px;
# ">
#
# Operaciones con tuplas
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Creación de tuplas.</li>
#
# </ul>
#
# </div>

# %%
# tuple1 = ("Foo", 34, 5.0, 34)

# print(tuple1)

# tuple2 = 1, 2, 3

# print(tuple2)

# tuple3 = tuple(range(10))

# print(tuple3)

# tuple4 = tuple([0, 1, 2, 3, 4])

# print(tuple4)

# %%
# Ojo con las tuplas de un elemento.
# Los paréntesis se interpretan como
# indicadores de precedencia de operadores.

# singleton_number = (1)

# type(singleton_number)

# %%
# Creación de una tupla de un elemento.

# singleton_tuple = (1,)

# print(type(singleton_tuple))

# print(singleton_tuple)

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Obtención del número de elementos.</li>
#
# </ul>
#
# </div>

# %%
# print(len(tuple1))

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Acceso por índice.</li>
#
# </ul>
#
# </div>

# %%
# tuple1 = ("Foo", 1, 2, 3)

# print(tuple1[0])              # Primer elemento

# print(tuple1[len(tuple1)-1])  # Último elemento

# print(tuple1[-1])             # Índices negativos comienzan desde el final

# print(tuple1[-len(tuple1)])   # Primer elemento

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>La asignación a tuplas falla porque son <b>inmutables</b>.</li>
#
# </ul>
#
# </div>

# %%
# tuple1[0] = "bar"

# %%
# print(id(tuple1))

# lista = list(tuple1)

# lista[0] = "bar"

# tuple1 = tuple(lista)

# print(id(tuple1))

# print(tuple1)

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Contar el número de ocurrencias de un elemento.</li>
#
# </ul>
#
# </div>

# %%
# tuple1 = ("Foo", 34, 5.0, 34)

# print(tuple1.count(34))

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Encontrar el índice de un elemento.</li>
#
# </ul>
#
# </div>

# %%
# tuple1 = ("Foo", 34, 5.0, 34)

# indice = tuple1.index(34)

# print(indice)

# print(tuple1[indice])

# %%
# Si el elemento no existe, se produce un error.

# tuple1 = ("Foo", 34, 5.0, 34)

# print(tuple1.index(1))

# %%
# Comprobar si existe antes de buscarlo.

# tuple1 = ("Foo", 34, 5.0, 34)

# elemento = 35

# if elemento in tuple1:
#     print(tuple1.index(elemento))
# else:
#     print(str(elemento) + " not found")

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Desempaquetar una tupla.</li>
#
# </ul>
#
# </div>

# %%
# tuple1 = (1, 2, 3, 4)

# a, b, c, d = tuple1      # a,b,c - a,b,c,d - a,b,_,_ - a,*_

# print(a)

# print(b)

# print(_)

# print(d)

# %%
# a, b, *resto = tuple1

# print(a)

# print(b)

# print(resto)

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:30px;
# font-weight:bold;
# margin-top:35px;
# margin-bottom:20px;
# ">
#
# 3.5 Secuencias
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ul>
#
# <li>Formalmente, objetos iterables no materializados.</li>
#
# <li>No son listas. Utiliza <code>list()</code> para materializarlas.</li>
#
# <li>Ejemplos: <code>range</code> o <code>enumerate</code>.</li>
#
# </ul>
#
# </div>

# %%
# list(range(0, 10, 2))

# %%
# lista = [10, 20, 30]

# print(list(enumerate(lista)))

# %%
# enumerate para iterar una colección (índice y valor)

# lista = [10, 20, 30]

# for index, value in enumerate(lista):
#     print("Index = " + str(index) + ". Value = " + str(value))

# for index, value in [(0, 10), (1, 20), (2, 30)]:
#     print("Index = " + str(index) + ". Value = " + str(value))

# %%
# enumerate para iterar una colección (índice y valor)

# for index, value in enumerate(range(0, 10, 2)):
#     print("Index = " + str(index) + ". Value = " + str(value))

# for value in enumerate(range(0, 10, 2)):
#     print(value)

# %%
# zip para unir, elemento a elemento, dos colecciones,
# retornando una lista de tuplas.
# Útil para iterar dos listas al mismo tiempo.

# nombres = ["Manolo", "Pepe", "Luis"]

# edades = [31, 34, 34, 45]

# for nombre, edad in zip(nombres, edades):
#     print("Nombre: " + nombre + ", edad: " + str(edad))

# %%
# nombres = ["Manolo", "Pepe", "Luis"]

# edades = [31, 34, 34]

# for i in range(0, len(nombres)):
#     print(f"Nombre es {nombres[i]} y edad es {edades[i]}")

# %%
# nombres = ["Manolo", "Pepe", "Luis"]

# edades = [31, 34, 34]

# jugadores = zip(nombres, edades)   # Genera una secuencia

# print(list(jugadores))

# print(type(jugadores))

# %%
# Listas de diferentes longitudes.

# nombres = ["Manolo", "Pepe", "Luis"]

# edades = [31, 34, 34, 44, 33]

# jugadores = zip(nombres, edades)

# print(list(jugadores))

# %%
# unzip

# nombres = ["Manolo", "Pepe", "Luis"]

# edades = [31, 34, 34]

# alturas = [120, 130, 140]

# jugadores = zip(nombres, edades, alturas)

# print(list(jugadores))

# ns, es, al = zip(*jugadores)

# print(list(ns))

# print(es)

# print(al)

# %%
# nombres = ["Manolo", "Pepe", "Luis"]

# edades = [31, 34, 34]

# dd = [23, 34, 45]

# jugadores_z = zip(nombres, edades, dd)

# print(list(jugadores_z))

# jugadores_uz = zip(*jugadores_z)

# print(list(jugadores_uz))

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:30px;
# font-weight:bold;
# margin-top:35px;
# margin-bottom:20px;
# ">
#
# 3.6 Para terminar, volvemos a enfatizar un matiz importante…
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <p><b>En Python todo son objetos.</b></p>
#
# <p>Cada objeto tiene:</p>
#
# <ul>
#
# <li><b>Identidad:</b> nunca cambia una vez creado. Es comparable con una dirección de memoria. El operador <code>is</code> compara la identidad y la función <code>id()</code> devuelve dicha identidad.</li>
#
# <li><b>Tipo:</b> determina los posibles valores y operaciones que puede realizar el objeto. La función <code>type()</code> devuelve el tipo y este no cambia.</li>
#
# <li><b>Valor:</b> puede corresponder a objetos mutables o inmutables.</li>
#
# </ul>
#
# <p><b>Tipos mutables:</b> <code>list</code>, <code>dict</code>, <code>set</code> y los tipos definidos por el usuario.</p>
#
# <p><b>Tipos inmutables:</b> <code>int</code>, <code>float</code>, <code>bool</code>, <code>str</code> y <code>tuple</code>.</p>
#
# </div>

# %%
# Asignación

# list_numbers = [1, 2, 3]      # Lista (mutable)

# tuple_numbers = (1, 2, 3)     # Tupla (inmutable)

# print(list_numbers[0])

# print(tuple_numbers[0])

# list_numbers[0] = 100

# tuple_numbers[0] = 100

# print(list_numbers)

# print(tuple_numbers)

# tuple_l_numbers = list(tuple_numbers)

# tuple_l_numbers[0] = 100

# tuple_numbers = tuple(tuple_l_numbers)

# print(tuple_numbers)

# %%
# Identidad

# list_numbers = [1, 2, 3]

# tuple_numbers = (1, 2, 3)

# print("Id list_numbers: " + str(id(list_numbers)))

# print("Id tuple_numbers: " + str(id(tuple_numbers)))

# list_numbers += [4, 5, 6]      # La lista original se extiende

# tuple_numbers += (4, 5, 6)     # Se crea un nuevo objeto

# print(list_numbers)

# print(tuple_numbers)

# print("Id list_numbers: " + str(id(list_numbers)))

# print("Id tuple_numbers: " + str(id(tuple_numbers)))

# %%
# Referencias

# list_numbers = [1, 2, 3]

# list_numbers_2 = list_numbers    # list_numbers_2 referencia a list_numbers

# print("Id list_numbers: " + str(id(list_numbers)))

# print("Id list_numbers_2: " + str(id(list_numbers_2)))

# list_numbers.append(4)           # Se actualiza list_numbers_2 también

# print(list_numbers)

# print(list_numbers_2)

# print("Id list_numbers: " + str(id(list_numbers)))

# print("Id list_numbers_2: " + str(id(list_numbers_2)))

# %%
# text = "Hola"     # Inmutable

# text_2 = text     # Referencia

# print("Id text: " + str(id(text)))

# print("Id text_2: " + str(id(text_2)))

# text += " Mundo"

# print(text)

# print(text_2)

# print("Id text: " + str(id(text)))

# print("Id text_2: " + str(id(text_2)))

# %%
# teams = ["Team A", "Team B", "Team C"]     # Mutable

# player = (23, teams)                       # Tupla (inmutable)

# print(type(player))

# print(player)

# print(id(player))

# teams[2] = "Team J"

# print(player)

# print(id(player))

# player[1][0] = "Team XX"

# print(teams)

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:30px;
# font-weight:bold;
# margin-top:35px;
# margin-bottom:20px;
# ">
#
# 3.7 Ejercicios
#
# </div>
#
# <div style="
# font-family:'Times New Roman', serif;
# font-size:18px;
# line-height:1.8;
# ">
#
# <ol>
#
# <li>
# Escribe un programa que muestre por pantalla la concatenación de un número y una cadena de caracteres. Para obtener esta concatenación puedes usar uno de los operadores explicados en este tema.<br><br>
#
# <b>Ejemplo:</b> dado el número <code>3</code> y la cadena <code>'abc'</code>, el programa mostrará la cadena <code>'3abc'</code>.
# </li>
#
# <br>
#
# <li>
# Escribe un programa que muestre por pantalla un valor booleano que indique si un número entero <code>N</code> está contenido en un intervalo semiabierto <code>[a,b)</code>, el cual establece una cota inferior <code>a</code> (inclusive) y una cota superior <code>b</code> (exclusive) para <code>N</code>.
# </li>
#
# <br>
#
# <li>
# Escribe un programa que, dados dos <i>strings</i> <code>S1</code> y <code>S2</code> y dos números enteros <code>N1</code> y <code>N2</code>, determine si el <i>substring</i> que en <code>S1</code> se extiende desde la posición <code>N1</code> hasta la <code>N2</code> (ambos inclusive) está contenido en <code>S2</code>.
# </li>
#
# <br>
#
# <li>
# Dada una lista con elementos duplicados, escribir un programa que muestre una nueva lista con el mismo contenido que la primera, pero sin elementos duplicados.
# </li>
#
# <br>
#
# <li>
# Escribe un programa que, dada una lista de <i>strings</i> <code>L</code>, un <i>string</i> <code>s</code> perteneciente a <code>L</code> y un <i>string</i> <code>t</code>, reemplace <code>s</code> por <code>t</code> en <code>L</code>. El programa debe mostrar la lista resultante por pantalla.
# </li>
#
# <br>
#
# <li>
# Escribe un programa que defina una tupla con elementos numéricos, reemplace el valor del último por un valor diferente y muestre la tupla por pantalla. Recuerda que las tuplas son inmutables. Tendrás que usar objetos intermedios.
# </li>
#
# <br>
#
# <li>
# Dada la lista <code>[1,2,3,4,5,6,7,8]</code>, escribe un programa que, a partir de esta lista, obtenga la lista <code>[8,6,4,2]</code> y la muestre por pantalla.
# </li>
#
# <br>
#
# <li>
# Escribe un programa que, dada una tupla y un índice válido <code>i</code>, elimine el elemento de la tupla que se encuentra en la posición <code>i</code>. Para este ejercicio solo puedes usar objetos de tipo tupla. No puedes convertir la tupla a una lista, por ejemplo.
# </li>
#
# <br>
#
# <li>
# Escribe un programa que obtenga la mediana de una lista de números. Recuerda que la mediana <code>M</code> de una lista de números <code>L</code> es el número que cumple la siguiente propiedad: la mitad de los números de <code>L</code> son superiores a <code>M</code> y la otra mitad son inferiores. Cuando el número de elementos de <code>L</code> es par, se puede considerar que hay dos medianas. No obstante, en este ejercicio consideraremos que únicamente existe una mediana.
# </li>
#
# </ol>
#
# </div>

# %% [markdown]
# <div style="
# font-family:'Times New Roman', serif;
# font-size:30px;
# font-weight:bold;
# margin-top:35px;
# margin-bottom:20px;
# ">
#
# 4 Soluciones
#
# </div>

# %%
# Ejercicio 1

x = 3
y = "abc"

print(str(x) + y)
# Out:
# 3abc

# %%
# Ejercicio 2

N = 5
a = 0
b = 6

# print(a <= N)
# print(N < b)

print(a <= N and N < b)
# Out:
# True

# %%
# Ejercicio 3

S1 = "Java"
S2 = "JavaScript"

N1 = 0
N2 = 3

print(S1[N1:N2 + 1] in S2)
# Out:
# True

# %%
# Ejercicio 4

L = [1, 2, 2, 3, 3, 2, 3, 1, 4, 5, 4, 5, 5]

print(list(set(L)))
# Out:
# [1, 2, 3, 4, 5]

# %%
# Ejercicio 5

# Escribe un programa que, dada una lista de strings L,
# un string s perteneciente a L y un string t,
# reemplace s por t en L.
# El programa debe mostrar la lista resultante por pantalla.

L = ["Python", "Java", "C++", "Kotlin"]

s = "Java"
t = "JavaScript"

indice = L.index(s)

L[indice] = t

print(L)
# Out:
# ['Python', 'JavaScript', 'C++', 'Kotlin']

# %%
# # Ejercicio 6
# #Escribe un programa que defina una tupla con elementos numéricos, reemplace el␣
# ↪valor del último por un valor diferente y muestre
# #la tupla por pantalla. Recuerda que las tuplas son inmutables. Tendrás que␣
# ↪usar objetos intermedios.
tupla = (1,2,3,4)
lista = list(tupla)
lista[-1] = 5
print(tuple(lista))
# Out:
# (1, 2, 3, 5)

# %%
# # Ejercicio 7
# #Dada la lista [1,2,3,4,5,6,7,8] escribe un programa que, a partir de esta␣
# ↪lista,
# #obtenga la lista [8,6,4,2] y la muestre por pantalla.
lista = [1,2,3,4,5,6,7,8]
print(lista[-1::-2]) #(inicio, fin, paso)
# Out:
# [8, 6, 4, 2]

# %%
# # Ejercicio 8
# #Escribe un programa que, dada una tupla y un índice válido i, elimine el␣
# ↪elemento de la tupla que se encuentra en la posición i.
# #Para este ejercicio sólo puedes usar objetos de tipo tupla. No puedes convetir␣
# ↪la tupla a una lista, por ejemplo.
tupla = ('a', 'b', 'c', 'd', 'e', 'f')
i = 3
print(tupla[:i] + tupla[i+1:])
# Out:
# ('a', 'b', 'c', 'e', 'f')

# %%
# # Ejercicio 9
# #Escribe un programa que obtenga la mediana de una lista de números. Recuerda␣
# ↪que la mediana M de una lista de números L
# #es el número que cumple la siguiente propiedad: la mitad de los números de L␣
# ↪son superiores a M y la otra mitad son inferiores.
# #Cuando el número de elementos de L es
# #par, se puede considerar que hay dos medianas. No obstante, en este ejercicio␣
# ↪consideraremos que únicamente existe una mediana.
L = [21, 9, 1, 5.5, 19, 3, 15]
L.sort()
print(L)
mediana = L[len(L)//2]
print(mediana)
# Out:
# [1, 3, 5.5, 9, 15, 19, 21]
# 9
